# %%
# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 필요한 패키지와 라이브러리를 가져옴
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np

data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([ -64,  -28,  -99,  -31, -108,  -51,  -98, -140, -211, -194, -106,
#         -59,  -17,   32,   14,   76,  134,  215,  232,  273,  191,  219,
#         165,   74,   75,  129,  212,  250,  194,  270,  205,  266,  219,
#         144,   69,   41,   72,  -28,   -1,   37,  -10,  -30,   62,   29,
#         125,  206,  123,   82,   46,  -30], dtype=int32)

# %%
plt.plot(range(50), data, 'r')
mpl.rcParams['axes.unicode_minus'] = False
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.1.1
# 설치 위치:  c:\users\sewook kim\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\Sewook KIM\.matplotlib
# 캐시 위치:  C:\Users\Sewook KIM\.matplotlib

# %%
print ('설정파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정파일 위치:  c:\users\sewook kim\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('숫자 분포도 보기')
plt.show()
