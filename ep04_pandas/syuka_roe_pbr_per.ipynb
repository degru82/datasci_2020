# %% [markdown]
# # 오늘의 목표는 이렇습니다
# - 오늘은 참여형이라기보다, 흥미유발형으로
# - 주식 초보인 우리가 주식투자전략을 시뮬레이션하는 시스템을 구축하고,
# - 여기에 간단한 아이디어를 검증 해보는 것을 목표로 합니다.
# - 다음 시간에는, 참여형으로 여러분의 아이디어를 검증하는 것을 목표로!
#
# ## 아니 근데 대관절 왠 주식투자?
# - 이게 참으로 데이터 사이언스 하기 좋은 주제
# - 판다스가 나옴, 괴물같은 모습으로!
#
# ## 오늘의 참고자료
# - [슈카형이 설명하는 주식지표와 워렌버핏 가치투자](https://youtu.be/uhqFaT0YI1w)
# - [주식용어정리 1편 - ROE, PER, PBR](https://m.blog.naver.com/lifadviser/221276226054)
# - [Naver Finance 국내증시 Data 수집](https://jsp-dev.tistory.com/entry/PythonBS4-Naver-Finance-%EA%B5%AD%EB%82%B4-%EC%A6%9D%EC%8B%9C-%EA%B8%B0%EC%B4%88-Data-%EC%88%98%EC%A7%91)

# %%
import pandas as pd

# %%
import requests

nhn_url = 'https://finance.naver.com/sise/field_submit.nhn' \
    '?menu=market_sum' \
    '&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page={}' \
    '&fieldIds=market_sum' \
    '&fieldIds=operating_profit' \
    '&fieldIds=open_val' \
    '&fieldIds=property_total' \
    '&fieldIds=debt_total' \
    '&fieldIds=listed_stock_cnt'

res = requests.get(nhn_url.format(1), verify=False)
# Out:
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
df3 = pd.read_html(res.text)

# %%
df4 = df3[1][ df3[1]['N'].notna()]
df4.head()
# Out:
#      N       종목명       현재가      전일비     등락률     액면가        시가      상장주식수  \
# 1  1.0      삼성전자   54900.0      0.0   0.00%   100.0   55800.0  5969783.0
# 2  2.0    SK하이닉스   90100.0    900.0  -0.99%  5000.0   91000.0   728002.0
# 3  3.0  삼성바이오로직스  679000.0  15000.0  +2.26%  2500.0  679000.0    66165.0
# 4  4.0     삼성전자우   47900.0    100.0  +0.21%   100.0   48300.0   822887.0
# 5  5.0     NAVER  237500.0   3000.0  -1.25%   100.0  240000.0   164263.0
#
#         시가총액       자산총계      부채총계      영업이익  토론실
# 1  3277411.0  3525645.0  896841.0  277685.0  NaN
# 2   655930.0   647895.0  168463.0   27127.0  NaN
# 3   449260.0    59116.0   15572.0     917.0  NaN
# 4   394163.0        NaN       NaN       NaN  NaN
# 5   390126.0   122995.0   57956.0    7101.0  NaN

# %%
df5 = df4.loc[:, ['N', '종목명', '현재가', '시가', '상장주식수', '시가총액', '자산총계', '부채총계', '영업이익']]
df5['N'] = df5['N'].astype('int')
df5.index = df5['N']
df5 = df5.drop(axis=1, columns='N')
df5.tail()
# Out:
#         종목명       현재가        시가     상장주식수     시가총액       자산총계       부채총계  \
# N
# 46      오리온  128500.0  130500.0   39536.0  50804.0    24523.0     7848.0
# 47     아모레G   57900.0   59400.0   82458.0  47743.0    82814.0    18012.0
# 48   미래에셋대우    6950.0    7170.0  658316.0  45753.0  1331498.0  1239562.0
# 49   현대글로비스  122000.0  124500.0   37500.0  45750.0   101297.0    54595.0
# 50  LG디스플레이   12700.0   12900.0  357816.0  45443.0   355746.0   230863.0
#
#        영업이익
# N
# 46   3276.0
# 47   4982.0
# 48   7280.0
# 49   8765.0
# 50 -13594.0

# %%
naverfin = pd.DataFrame()
num_total = 32

query_url = 'https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn%3F%26page%3D{}&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt'

for i in range(1, num_total+1):
    
    print(nhn_url.format(i))
    res = requests.get(query_url.format(i), verify=False)
    
    tmp_df = pd.read_html(res.text)
    #print(tmp_df[1].columns)

    tmp_df = tmp_df[1][tmp_df[1]['N'].notna()].loc[:, ['N', '종목명', '현재가', '상장주식수', '시가총액', '자산총계', '부채총계', '영업이익']]
    
    
    tmp_df['N'] = tmp_df['N'].astype('int')
    tmp_df.index = tmp_df['N']
    tmp_df = tmp_df.drop(axis=1, columns='N')
    print(tmp_df.head())
    
    naverfin = naverfin.append(tmp_df)
    
naverfin.shape
# Out:
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=1&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#         종목명       현재가      상장주식수       시가총액       자산총계      부채총계      영업이익
# N
# 1      삼성전자   54900.0  5969783.0  3277411.0  3525645.0  896841.0  277685.0
# 2    SK하이닉스   90100.0   728002.0   655930.0   647895.0  168463.0   27127.0
# 3  삼성바이오로직스  679000.0    66165.0   449260.0    59116.0   15572.0     917.0
# 4     삼성전자우   47900.0   822887.0   394163.0        NaN       NaN       NaN
# 5     NAVER  237500.0   164263.0   390126.0   122995.0   57956.0    7101.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=2&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#         종목명       현재가     상장주식수     시가총액      자산총계      부채총계    영업이익
# N
# 51  현대중공업지주  286500.0   15799.0  45263.0  257155.0  138308.0  6666.0
# 52   CJ제일제당  299000.0   15054.0  45012.0  262806.0  167992.0  8969.0
# 53    삼성중공업    6860.0  630000.0  43218.0  136001.0   83512.0 -6166.0
# 54   맥쿼리인프라   11600.0  349044.0  40489.0       NaN       NaN     NaN
# 55     현대건설   35650.0  111356.0  39698.0  182270.0   95120.0  8597.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=3&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                   종목명       현재가     상장주식수     시가총액     자산총계     부채총계    영업이익
# N
# 101  KODEX 200선물인버스2X    5110.0  416400.0  21278.0      NaN      NaN     NaN
# 102               오뚜기  583000.0    3605.0  21019.0  21521.0   8056.0  1483.0
# 103               팬오션    3880.0  534569.0  20741.0  44542.0  15546.0  2100.0
# 104              제일기획   18000.0  115041.0  20707.0  22528.0  12960.0  2058.0
# 105              부광약품   31900.0   64838.0  20683.0   3885.0    620.0    95.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=4&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#             종목명       현재가    상장주식수     시가총액     자산총계     부채총계    영업이익
# N
# 151       한솔케미칼  112500.0  11295.0  12707.0   9392.0   4186.0  1114.0
# 152      더블유게임즈   67900.0  18266.0  12402.0  10747.0   4276.0  1546.0
# 153        태영건설   16150.0  76400.0  12339.0  59161.0  43447.0  3912.0
# 154  KBSTAR 200   29030.0  41600.0  12076.0      NaN      NaN     NaN
# 155       두산솔루스   39350.0  30590.0  12037.0   4942.0   3536.0   102.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=5&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                 종목명       현재가    상장주식수    시가총액     자산총계     부채총계    영업이익
# N
# 201            대한유화  127000.0   6500.0  8255.0  20265.0   2479.0  1138.0
# 202            제일약품   55000.0  14705.0  8088.0   4016.0   2315.0     4.0
# 203            롯데제과  125500.0   6417.0  8053.0  27162.0  14154.0   973.0
# 204  KODEX 단기채권PLUS  102530.0   7805.0  8002.0      NaN      NaN     NaN
# 205              후성    8640.0  92607.0  8001.0   5289.0   2860.0   134.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=6&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#            종목명       현재가     상장주식수    시가총액      자산총계      부채총계    영업이익
# N
# 251        풀무원   15150.0   38091.0  5771.0   14846.0   10215.0   306.0
# 252     미래에셋생명    3250.0  177016.0  5753.0  380155.0  356790.0  1407.0
# 253    SK디스커버리   29950.0   19038.0  5702.0   50001.0   26769.0  1739.0
# 254      효성티앤씨  131500.0    4328.0  5691.0   32243.0   26414.0  3229.0
# 255  KOSEF 200   29150.0   18500.0  5393.0       NaN       NaN     NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=7&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                종목명      현재가     상장주식수    시가총액     자산총계     부채총계    영업이익
# N
# 301  TIGER 단기채권액티브  50375.0    8096.0  4078.0      NaN      NaN     NaN
# 302           우리종금    603.0  674203.0  4065.0  33990.0  30316.0   539.0
# 303             LF  13900.0   29240.0  4064.0  24171.0  10256.0   875.0
# 304       하이트진로홀딩스  17500.0   23207.0  4061.0  38367.0  28541.0  1009.0
# 305    KOSEF 200TR  33690.0   12050.0  4060.0      NaN      NaN     NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=8&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#               종목명       현재가    상장주식수    시가총액     자산총계    부채총계   영업이익
# N
# 351          송원산업   14250.0  24000.0  3420.0   8943.0  4587.0  593.0
# 352            경방   12400.0  27415.0  3399.0  13707.0  6292.0  320.0
# 353         한국쉘석유  261000.0   1300.0  3393.0   1411.0   432.0  257.0
# 354  HANARO 단기통안채  102615.0   3299.0  3385.0      NaN     NaN    NaN
# 355   TIGER TOP10    9480.0  35650.0  3380.0      NaN     NaN    NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=9&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#             종목명      현재가     상장주식수    시가총액     자산총계     부채총계    영업이익
# N
# 401   SBS미디어홀딩스   1855.0  139896.0  2595.0   6741.0    736.0    48.0
# 402        신성통상   1795.0  143708.0  2580.0   6896.0   4588.0   408.0
# 403          E1  37550.0    6860.0  2576.0  35950.0  23917.0  1063.0
# 404      에이블씨엔씨   9520.0   27033.0  2574.0   4333.0   1769.0    18.0
# 405  아모레G3우(전환)  36150.0    7092.0  2564.0      NaN      NaN     NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=10&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                          종목명      현재가    상장주식수    시가총액    자산총계    부채총계   영업이익
# N
# 451                    한국주철관   9440.0  22800.0  2152.0  3520.0   831.0   66.0
# 452                     동부건설   9820.0  21877.0  2148.0  8919.0  4713.0  555.0
# 453                  넥스트사이언스   6750.0  31800.0  2146.0  1294.0   475.0  -44.0
# 454  TIGER 차이나CSI300레버리지(합성)  19260.0  11100.0  2138.0     NaN     NaN    NaN
# 455                     한국철강   4625.0  46050.0  2130.0  8732.0  1483.0  122.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=11&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                             종목명      현재가    상장주식수    시가총액     자산총계    부채총계  \
# N
# 501         KBSTAR 코스닥150선물레버리지  10380.0  16720.0  1736.0      NaN     NaN
# 502                KINDEX 200TR  17285.0  10000.0  1728.0      NaN     NaN
# 503  TRUE 인버스 2X 천연가스 선물 ETN(H)  34525.0   5000.0  1726.0      NaN     NaN
# 504                       세진중공업   4495.0  38373.0  1725.0   4086.0  2463.0
# 505                        성신양회   7030.0  24516.0  1723.0  10294.0  6291.0
#
#       영업이익
# N
# 501    NaN
# 502    NaN
# 503    NaN
# 504   94.0
# 505  208.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=12&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#            종목명      현재가     상장주식수    시가총액     자산총계    부채총계   영업이익
# N
# 551    코오롱플라스틱   3950.0   38000.0  1501.0   3387.0  1411.0  103.0
# 552        쌍방울   1075.0  139360.0  1498.0   3404.0  1743.0 -103.0
# 553       세아제강  52700.0    2836.0  1495.0  10288.0  4576.0  459.0
# 554  HDC아이콘트롤스   9070.0   16460.0  1493.0   2372.0   686.0  130.0
# 555    NH투자증권우   7910.0   18871.0  1493.0      NaN     NaN    NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=13&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#          종목명       현재가    상장주식수    시가총액    자산총계    부채총계   영업이익
# N
# 601       벽산    1920.0  68560.0  1316.0  4627.0  1712.0  -38.0
# 602      STX    6640.0  19727.0  1310.0  5601.0  5038.0   17.0
# 603      BYC  209500.0    625.0  1309.0  6939.0  2596.0  234.0
# 604     화성산업   10500.0  12451.0  1307.0  6126.0  2416.0  296.0
# 605  현대비앤지스틸    8650.0  15079.0  1304.0  6086.0  2057.0  365.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=14&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#          종목명      현재가     상장주식수    시가총액    자산총계    부채총계   영업이익
# N
# 651     남광토건  11500.0    9829.0  1130.0  2026.0  1497.0   48.0
# 652      퍼스텍   2405.0   46765.0  1125.0  1821.0  1548.0  -47.0
# 653   인천도시가스  25600.0    4375.0  1120.0  3653.0  1803.0  120.0
# 654  YG PLUS   1915.0   58171.0  1114.0  1567.0   449.0   12.0
# 655     보해양조    873.0  127449.0  1113.0  1673.0   873.0 -111.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=15&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#          종목명     현재가    상장주식수   시가총액     자산총계     부채총계   영업이익
# N
# 701     한양증권  7450.0  12729.0  948.0  18222.0  15275.0  296.0
# 702      휴니드  6710.0  14116.0  947.0   2610.0   1451.0   88.0
# 703    콤텍시스템  1395.0  67851.0  947.0   1615.0    666.0   30.0
# 704    우리들제약  6900.0  13706.0  946.0   1000.0    438.0   12.0
# 705  KC그린홀딩스  4210.0  22435.0  945.0   8161.0   5218.0  215.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=16&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#       종목명      현재가    상장주식수   시가총액    자산총계    부채총계   영업이익
# N
# 751    조비  16200.0   5192.0  841.0   917.0   437.0   10.0
# 752   다스코   5450.0  15400.0  839.0  2147.0   914.0   31.0
# 753  호전실업  10450.0   8000.0  836.0  2923.0  1678.0  193.0
# 754  화천기계   3785.0  22000.0  833.0  1583.0   337.0  -93.0
# 755  사조오양   8790.0   9423.0  828.0  3112.0  1436.0  226.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=17&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                      종목명     현재가    상장주식수   시가총액    자산총계    부채총계   영업이익
# N
# 801                   혜인  5640.0  12713.0  717.0  2183.0  1228.0  118.0
# 802                 메타랩스  1355.0  52309.0  709.0   983.0   397.0  -20.0
# 803               대림B&Co  4250.0  16672.0  709.0  3092.0  1498.0   41.0
# 804  신한 레버리지 은 선물 ETN(H)  7075.0  10000.0  708.0     NaN     NaN    NaN
# 805                 대원화성  1710.0  41249.0  705.0  1305.0   511.0   67.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=18&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                  종목명       현재가    상장주식수   시가총액    자산총계    부채총계   영업이익
# N
# 851              체시스    2430.0  24000.0  583.0   886.0   619.0  -15.0
# 852    KBSTAR 금융채액티브  102295.0    570.0  583.0     NaN     NaN    NaN
# 853  KB KQ 우량주30 ETN   11575.0   5000.0  579.0     NaN     NaN    NaN
# 854           상신브레이크    2695.0  21471.0  579.0  4523.0  2754.0  157.0
# 855             대교우B    2975.0  19427.0  578.0     NaN     NaN    NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=19&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                   종목명      현재가    상장주식수   시가총액    자산총계    부채총계  영업이익
# N
# 901             평화홀딩스   3230.0  14625.0  472.0  5029.0  3789.0 -36.0
# 902              한성기업   7560.0   6210.0  469.0  2336.0  1837.0 -83.0
# 903             호텔신라우  62200.0    752.0  468.0     NaN     NaN   NaN
# 904  대신 철광석 선물 ETN(H)  23280.0   2000.0  466.0     NaN     NaN   NaN
# 905             삼아알미늄   4175.0  11000.0  459.0  2085.0   996.0  64.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=20&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                      종목명       현재가    상장주식수   시가총액    자산총계    부채총계   영업이익
# N
# 951  신한 레버리지 천연가스 선물 ETN    7515.0   5000.0  376.0     NaN     NaN    NaN
# 952         KBSTAR 국고채3년  113725.0    330.0  375.0     NaN     NaN    NaN
# 953                 이화산업   13400.0   2800.0  375.0  2827.0  1048.0  -17.0
# 954         KOSEF 코스닥150    5860.0   6380.0  374.0     NaN     NaN    NaN
# 955                케이탑리츠     802.0  46224.0  371.0  2108.0  1423.0  105.0
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=21&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명       현재가     상장주식수   시가총액    자산총계    부채총계   영업이익
# N
# 1001     KINDEX 중장기국공채액티브  103340.0     293.0  303.0     NaN     NaN    NaN
# 1002              하이골드12호    2310.0   13044.0  301.0   364.0    70.0   54.0
# 1003                 흥아해운     258.0  116733.0  301.0  4310.0  4000.0 -124.0
# 1004                일양약품우   67400.0     445.0  300.0     NaN     NaN    NaN
# 1005  삼성 레버리지 금 선물 ETN(H)   29920.0    1000.0  299.0     NaN     NaN    NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=22&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명      현재가   상장주식수   시가총액  자산총계  부채총계  영업이익
# N
# 1051      KOSEF 200선물레버리지  11690.0  2100.0  245.0   NaN   NaN   NaN
# 1052    ARIRANG KS로우볼가중TR  10225.0  2400.0  245.0   NaN   NaN   NaN
# 1053  신한 레버리지 미국달러 선물 ETN  12255.0  2000.0  245.0   NaN   NaN   NaN
# 1054   미래에셋 유럽 중형주 ETN(H)  12235.0  2000.0  245.0   NaN   NaN   NaN
# 1055       ARIRANG 단기우량채권  53105.0   460.0  244.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=23&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                            종목명      현재가   상장주식수   시가총액  자산총계  부채총계  영업이익
# N
# 1101  TRUE 레버리지 유로스탁스50 ETN(H)  10395.0  2000.0  208.0   NaN   NaN   NaN
# 1102            QV 조선 TOP5 ETN  10375.0  2000.0  208.0   NaN   NaN   NaN
# 1103       KOSEF 인도Nifty50(합성)  11505.0  1800.0  207.0   NaN   NaN   NaN
# 1104                  하이트진로2우B  18300.0  1130.0  207.0   NaN   NaN   NaN
# 1105             HANARO KRX300  13320.0  1550.0  206.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=24&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                         종목명      현재가   상장주식수   시가총액  자산총계  부채총계  영업이익
# N
# 1151      TIGER 미국달러선물인버스2X   8855.0  2000.0  177.0   NaN   NaN   NaN
# 1152       HANARO 200선물레버리지  14165.0  1250.0  177.0   NaN   NaN   NaN
# 1153  KODEX 글로벌4차산업로보틱스(합성)  12915.0  1350.0  174.0   NaN   NaN   NaN
# 1154   신한 코스피 콘도르 4/10% ETN   8650.0  2000.0  173.0   NaN   NaN   NaN
# 1155   KODEX 미국채울트라30년선물(H)  13225.0  1300.0  172.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=25&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                             종목명       현재가   상장주식수   시가총액  자산총계  부채총계  영업이익
# N
# 1201         신한 인버스 금 선물 ETN(H)    7100.0  2000.0  142.0   NaN   NaN   NaN
# 1202                   현대비앤지스틸우  129000.0   110.0  142.0   NaN   NaN   NaN
# 1203             삼성 미디어 테마주 ETN    7045.0  2000.0  141.0   NaN   NaN   NaN
# 1204  SMART 선진국MSCI World(합성 H)   14040.0  1000.0  140.0   NaN   NaN   NaN
# 1205             신한 콩 선물 ETN(H)    6985.0  2000.0  140.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=26&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명      현재가   상장주식수   시가총액  자산총계  부채총계  영업이익
# N
# 1251                계양전기우   8060.0  1400.0  113.0   NaN   NaN   NaN
# 1252     TIGER 200커버드콜ATM   9385.0  1200.0  113.0   NaN   NaN   NaN
# 1253                코리아써우   3795.0  2965.0  112.0   NaN   NaN   NaN
# 1254   미래에셋 원유선물혼합 ETN(H)  11190.0  1000.0  112.0   NaN   NaN   NaN
# 1255  KODEX S&P글로벌인프라(합성)  11135.0   997.0  111.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=27&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                                 종목명      현재가   상장주식수  시가총액  자산총계  부채총계  영업이익
# N
# 1301             TRUE 인버스 엔선물 ETN B   9375.0  1000.0  94.0   NaN   NaN   NaN
# 1302           HANARO 글로벌럭셔리S&P(합성)  11715.0   800.0  94.0   NaN   NaN   NaN
# 1303  TRUE S&P500 양매도 4% OTM ETN(H)   9370.0  1000.0  94.0   NaN   NaN   NaN
# 1304  신한 코스피 월별 양매도 5% 콜 2206-1 ETN   9365.0  1000.0  94.0   NaN   NaN   NaN
# 1305         신한 인버스 달러인덱스 선물 ETN(H)   9355.0  1000.0  94.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=28&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                      종목명      현재가  상장주식수  시가총액  자산총계  부채총계  영업이익
# N
# 1351     HANARO 200선물인버스  13715.0  600.0  82.0   NaN   NaN   NaN
# 1352    TIGER KRX300레버리지  10240.0  800.0  82.0   NaN   NaN   NaN
# 1353      KINDEX 스마트하이베타  10210.0  800.0  82.0   NaN   NaN   NaN
# 1354     KINDEX 삼성그룹동일가중  13545.0  600.0  81.0   NaN   NaN   NaN
# 1355  KINDEX 러시아MSCI(합성)  27050.0  300.0  81.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=29&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                            종목명      현재가   상장주식수  시가총액  자산총계  부채총계  영업이익
# N
# 1401             TREX 펀더멘탈 200  27595.0   250.0  69.0   NaN   NaN   NaN
# 1402                     성신양회우   9370.0   736.0  69.0   NaN   NaN   NaN
# 1403  QV 인버스 레버리지 MSCI 선진국 ETN   9800.0   700.0  69.0   NaN   NaN   NaN
# 1404           삼성 건축자재 테마주 ETN   3410.0  2000.0  68.0   NaN   NaN   NaN
# 1405                 KOSEF 고배당   6795.0  1000.0  68.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=30&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#               종목명      현재가  상장주식수  시가총액  자산총계  부채총계  영업이익
# N
# 1451   KINDEX 인버스   7300.0  800.0  58.0   NaN   NaN   NaN
# 1452       크라운제과우   7530.0  774.0  58.0   NaN   NaN   NaN
# 1453   TIGER 지주회사  10560.0  550.0  58.0   NaN   NaN   NaN
# 1454  KODEX 경기소비재   9630.0  600.0  58.0   NaN   NaN   NaN
# 1455  KBSTAR 게임테마  10470.0  550.0  58.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=31&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명      현재가  상장주식수  시가총액  자산총계  부채총계  영업이익
# N
# 1501  ARIRANG 심천차이넥스트(합성)   9230.0  500.0  46.0   NaN   NaN   NaN
# 1502    KINDEX 국채선물10년인버스  92070.0   50.0  46.0   NaN   NaN   NaN
# 1503          TIGER 중소형가치   8310.0  550.0  46.0   NaN   NaN   NaN
# 1504     ARIRANG KRX300IT  13235.0  340.0  45.0   NaN   NaN   NaN
# 1505                흥국화재우   5850.0  768.0  45.0   NaN   NaN   NaN
# https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn?&page=32&fieldIds=market_sum&fieldIds=operating_profit&fieldIds=open_val&fieldIds=property_total&fieldIds=debt_total&fieldIds=listed_stock_cnt
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                    종목명      현재가  상장주식수  시가총액  자산총계  부채총계  영업이익
# N
# 1551        TREX 중소형가치   6750.0  300.0  20.0   NaN   NaN   NaN
# 1552      KBSTAR 200금융   6885.0  280.0  19.0   NaN   NaN   NaN
# 1553  TIGER 원유선물인버스(H)  12360.0  150.0  19.0   NaN   NaN   NaN
# 1554   TIGER 코스닥150로우볼  12760.0  140.0  18.0   NaN   NaN   NaN
# 1555    TIGER 200 철강소재   6045.0  280.0  17.0   NaN   NaN   NaN
# (1557, 7)

# %%
naverfin
# Out:
#                    종목명       현재가      상장주식수       시가총액       자산총계      부채총계  \
# N
# 1                 삼성전자   54900.0  5969783.0  3277411.0  3525645.0  896841.0
# 2               SK하이닉스   90100.0   728002.0   655930.0   647895.0  168463.0
# 3             삼성바이오로직스  679000.0    66165.0   449260.0    59116.0   15572.0
# 4                삼성전자우   47900.0   822887.0   394163.0        NaN       NaN
# 5                NAVER  237500.0   164263.0   390126.0   122995.0   57956.0
# ...                ...       ...        ...        ...        ...       ...
# 1553  TIGER 원유선물인버스(H)   12360.0      150.0       19.0        NaN       NaN
# 1554   TIGER 코스닥150로우볼   12760.0      140.0       18.0        NaN       NaN
# 1555    TIGER 200 철강소재    6045.0      280.0       17.0        NaN       NaN
# 1556     TIGER 200 산업재    4260.0      280.0       12.0        NaN       NaN
# 1557     KBSTAR 200산업재    7785.0      140.0       11.0        NaN       NaN
#
#           영업이익
# N
# 1     277685.0
# 2      27127.0
# 3        917.0
# 4          NaN
# 5       7101.0
# ...        ...
# 1553       NaN
# 1554       NaN
# 1555       NaN
# 1556       NaN
# 1557       NaN
#
# [1557 rows x 7 columns]

# %%
naverfin[81:100]
# Out:
#             종목명       현재가     상장주식수     시가총액      자산총계      부채총계     영업이익
# N
# 82         삼성증권   30300.0   89300.0  27058.0  447296.0  397803.0   5176.0
# 83        휠라홀딩스   43450.0   60752.0  26397.0   37702.0   19693.0   4707.0
# 84           CJ   90100.0   29177.0  26288.0  403814.0  257663.0  15092.0
# 85       BGF리테일  152000.0   17284.0  26272.0   21724.0   15498.0   1966.0
# 86       한국항공우주   26900.0   97475.0  26221.0   43671.0   31840.0   2756.0
# 87      삼성엔지니어링   13350.0  196000.0  26166.0   45452.0   32424.0   3855.0
# 88         롯데쇼핑   92300.0   28289.0  26111.0  339726.0  220709.0   4279.0
# 89        하이트진로   36800.0   70134.0  25809.0   32709.0   22377.0    882.0
# 90       현대차2우B   69400.0   36485.0  25321.0       NaN       NaN      NaN
# 91         현대해상   27200.0   89400.0  24317.0  463938.0  418834.0   3953.0
# 92          신세계  246000.0    9845.0  24219.0  130185.0   75034.0   4678.0
# 93         금호석유   77200.0   30468.0  23521.0   45380.0   19085.0   3678.0
# 94         GS건설   28450.0   80098.0  22788.0  131712.0   90282.0   7673.0
# 95          SKC   60200.0   37535.0  22596.0   39730.0   22466.0   1551.0
# 96       한미사이언스   33600.0   66011.0  22180.0    9108.0    2651.0    380.0
# 97      일진머티리얼즈   47550.0   46111.0  21926.0   10369.0    2127.0    469.0
# 98        메리츠증권    3495.0  617311.0  21575.0  381099.0  340907.0   6799.0
# 99   KODEX 단기채권  102365.0   20909.0  21403.0       NaN       NaN      NaN
# 100          한샘   90800.0   23534.0  21369.0   12026.0    5893.0    558.0

# %%
naverfin.shape
# Out:
# (1557, 7)

# %%
naverfin['myRoe'] = naverfin['영업이익']/(naverfin['자산총계']-naverfin['부채총계'])

# %%
naverfin[80:100]
# Out:
#             종목명       현재가     상장주식수     시가총액      자산총계      부채총계     영업이익  \
# N
# 81         쌍용양회    5390.0  503860.0  27158.0   33288.0   15263.0   2284.0
# 82         삼성증권   30300.0   89300.0  27058.0  447296.0  397803.0   5176.0
# 83        휠라홀딩스   43450.0   60752.0  26397.0   37702.0   19693.0   4707.0
# 84           CJ   90100.0   29177.0  26288.0  403814.0  257663.0  15092.0
# 85       BGF리테일  152000.0   17284.0  26272.0   21724.0   15498.0   1966.0
# 86       한국항공우주   26900.0   97475.0  26221.0   43671.0   31840.0   2756.0
# 87      삼성엔지니어링   13350.0  196000.0  26166.0   45452.0   32424.0   3855.0
# 88         롯데쇼핑   92300.0   28289.0  26111.0  339726.0  220709.0   4279.0
# 89        하이트진로   36800.0   70134.0  25809.0   32709.0   22377.0    882.0
# 90       현대차2우B   69400.0   36485.0  25321.0       NaN       NaN      NaN
# 91         현대해상   27200.0   89400.0  24317.0  463938.0  418834.0   3953.0
# 92          신세계  246000.0    9845.0  24219.0  130185.0   75034.0   4678.0
# 93         금호석유   77200.0   30468.0  23521.0   45380.0   19085.0   3678.0
# 94         GS건설   28450.0   80098.0  22788.0  131712.0   90282.0   7673.0
# 95          SKC   60200.0   37535.0  22596.0   39730.0   22466.0   1551.0
# 96       한미사이언스   33600.0   66011.0  22180.0    9108.0    2651.0    380.0
# 97      일진머티리얼즈   47550.0   46111.0  21926.0   10369.0    2127.0    469.0
# 98        메리츠증권    3495.0  617311.0  21575.0  381099.0  340907.0   6799.0
# 99   KODEX 단기채권  102365.0   20909.0  21403.0       NaN       NaN      NaN
# 100          한샘   90800.0   23534.0  21369.0   12026.0    5893.0    558.0
#
#         myRoe
# N
# 81   0.126713
# 82   0.104580
# 83   0.261369
# 84   0.103263
# 85   0.315773
# 86   0.232947
# 87   0.295901
# 88   0.035953
# 89   0.085366
# 90        NaN
# 91   0.087642
# 92   0.084822
# 93   0.139875
# 94   0.185204
# 95   0.089840
# 96   0.058851
# 97   0.056904
# 98   0.169163
# 99        NaN
# 100  0.090983

# %%
top_roe = naverfin.sort_values(by=['myRoe'], ascending=False)

# %%
top_roe
# Out:
#                    종목명       현재가     상장주식수     시가총액     자산총계     부채총계    영업이익  \
# N
# 1008           키위미디어그룹     150.0  197285.0    296.0    568.0    663.0  -108.0
# 254              효성티앤씨  131500.0    4328.0   5691.0  32243.0  26414.0  3229.0
# 45                 코웨이   73400.0   73800.0  54169.0  28550.0  17778.0  4583.0
# 320             효성첨단소재   85500.0    4480.0   3830.0  25311.0  21257.0  1583.0
# 529               고려개발   10500.0   15219.0   1598.0   6134.0   4444.0   631.0
# ...                ...       ...       ...      ...      ...      ...     ...
# 1553  TIGER 원유선물인버스(H)   12360.0     150.0     19.0      NaN      NaN     NaN
# 1554   TIGER 코스닥150로우볼   12760.0     140.0     18.0      NaN      NaN     NaN
# 1555    TIGER 200 철강소재    6045.0     280.0     17.0      NaN      NaN     NaN
# 1556     TIGER 200 산업재    4260.0     280.0     12.0      NaN      NaN     NaN
# 1557     KBSTAR 200산업재    7785.0     140.0     11.0      NaN      NaN     NaN
#
#          myRoe
# N
# 1008  1.136842
# 254   0.553954
# 45    0.425455
# 320   0.390479
# 529   0.373373
# ...        ...
# 1553       NaN
# 1554       NaN
# 1555       NaN
# 1556       NaN
# 1557       NaN
#
# [1557 rows x 8 columns]

# %% [markdown]
# __아니 이럴수가,
# 영업이익이 음수인데도 ROE가 높다는게 말이되나?
# 하고 봤더니, 부채가 자산을 눌렀네
# 그렇다면, 중간 단계를 거쳐서 다시 계산해보지 뭐__

# %%
naverfin['자본'] = naverfin['자산총계'] - naverfin['부채총계']
naverfin.head()
# Out:
#         종목명       현재가      상장주식수       시가총액       자산총계      부채총계      영업이익  \
# N
# 1      삼성전자   54900.0  5969783.0  3277411.0  3525645.0  896841.0  277685.0
# 2    SK하이닉스   90100.0   728002.0   655930.0   647895.0  168463.0   27127.0
# 3  삼성바이오로직스  679000.0    66165.0   449260.0    59116.0   15572.0     917.0
# 4     삼성전자우   47900.0   822887.0   394163.0        NaN       NaN       NaN
# 5     NAVER  237500.0   164263.0   390126.0   122995.0   57956.0    7101.0
#
#       myRoe         자본
# N
# 1  0.105632  2628804.0
# 2  0.056582   479432.0
# 3  0.021059    43544.0
# 4       NaN        NaN
# 5  0.109181    65039.0

# %%
naverfin.head()
# Out:
#         종목명       현재가      상장주식수       시가총액       자산총계      부채총계      영업이익  \
# N
# 1      삼성전자   54900.0  5969783.0  3277411.0  3525645.0  896841.0  277685.0
# 2    SK하이닉스   90100.0   728002.0   655930.0   647895.0  168463.0   27127.0
# 3  삼성바이오로직스  679000.0    66165.0   449260.0    59116.0   15572.0     917.0
# 4     삼성전자우   47900.0   822887.0   394163.0        NaN       NaN       NaN
# 5     NAVER  237500.0   164263.0   390126.0   122995.0   57956.0    7101.0
#
#       myRoe         자본
# N
# 1  0.105632  2628804.0
# 2  0.056582   479432.0
# 3  0.021059    43544.0
# 4       NaN        NaN
# 5  0.109181    65039.0

# %%
naverfin.sort_values(by=['자본', 'myRoe'], ascending=[False, False])
# Out:
#                    종목명       현재가      상장주식수       시가총액       자산총계       부채총계  \
# N
# 1                 삼성전자   54900.0  5969783.0  3277411.0  3525645.0   896841.0
# 9                  현대차  112000.0   213668.0   239308.0  1945122.0  1181465.0
# 21                한국전력   22500.0   641964.0   144442.0  1975978.0  1287081.0
# 15                  SK  253000.0    70360.0   178012.0  1320207.0   798380.0
# 2               SK하이닉스   90100.0   728002.0   655930.0   647895.0   168463.0
# ...                ...       ...        ...        ...        ...        ...
# 1553  TIGER 원유선물인버스(H)   12360.0      150.0       19.0        NaN        NaN
# 1554   TIGER 코스닥150로우볼   12760.0      140.0       18.0        NaN        NaN
# 1555    TIGER 200 철강소재    6045.0      280.0       17.0        NaN        NaN
# 1556     TIGER 200 산업재    4260.0      280.0       12.0        NaN        NaN
# 1557     KBSTAR 200산업재    7785.0      140.0       11.0        NaN        NaN
#
#           영업이익     myRoe         자본
# N
# 1     277685.0  0.105632  2628804.0
# 9      36055.0  0.047214   763657.0
# 21    -12765.0 -0.018530   688897.0
# 15     39499.0  0.075694   521827.0
# 2      27127.0  0.056582   479432.0
# ...        ...       ...        ...
# 1553       NaN       NaN        NaN
# 1554       NaN       NaN        NaN
# 1555       NaN       NaN        NaN
# 1556       NaN       NaN        NaN
# 1557       NaN       NaN        NaN
#
# [1557 rows x 9 columns]

# %% [markdown]
# # 친절한 이웃, 네이버에서 ROE, PBR, PER까지 가져오자
# - 사실은 그냥 처음부터 데이터프레임 만들때 가져왔으면 되었지만,
# - 연습도 할 겸, 두 개의 데이터 프레임을 옆으로 붙이는 걸 해보겠습니다

# %%
kindnaver_url = 'https://finance.naver.com/sise/field_submit.nhn?menu=market_sum&returnUrl=http%3A%2F%2Ffinance.naver.com%2Fsise%2Fsise_market_sum.nhn%3F%26page%3D{}&fieldIds=per&fieldIds=roe&fieldIds=pbr'

res = requests.get(kindnaver_url.format(1), verify=False)
tmp_df = pd.read_html(res.text)

tmp_df[1].head()
# Out:
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#      N       종목명       현재가      전일비     등락률     액면가     PER   ROE    PBR  토론실  \
# 0  NaN       NaN       NaN      NaN     NaN     NaN     NaN   NaN    NaN  NaN
# 1  1.0      삼성전자   54900.0      0.0   0.00%   100.0   17.52  8.69   1.44  NaN
# 2  2.0    SK하이닉스   90100.0    900.0  -0.99%  5000.0   42.08  4.25   1.28  NaN
# 3  3.0  삼성바이오로직스  679000.0  15000.0  +2.26%  2500.0  161.59  4.77  10.23  NaN
# 4  4.0     삼성전자우   47900.0    100.0  +0.21%   100.0   15.28   NaN   1.26  NaN
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
res = requests.get

# %%
indicators = pd.DataFrame()

for i in range(1, num_total+1):
    res = requests.get(kindnaver_url.format(i), verify=False)
    
    tmp_df = pd.read_html(res.text)
    #print(tmp_df[1].columns)

    tmp_df2 = tmp_df[1][tmp_df[1]['N'].notna()].loc[:, ['N', '종목명', 'PER', 'ROE', 'PBR']]
    
    
    tmp_df2['N'] = tmp_df2['N'].astype('int')
    tmp_df2.index = tmp_df2['N']
    tmp_df2 = tmp_df2.drop(axis=1, columns='N')
    print(tmp_df2.head())
    
    indicators = indicators.append(tmp_df2)
    
indicators.shape
# Out:
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#         종목명     PER    ROE    PBR
# N
# 1      삼성전자   17.52   8.69   1.44
# 2    SK하이닉스   42.08   4.25   1.28
# 3  삼성바이오로직스  161.59   4.77  10.23
# 4     삼성전자우   15.28    NaN   1.26
# 5     NAVER   61.32  10.56   5.20
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#         종목명    PER    ROE   PBR
# N
# 51  현대중공업지주 -36.47   2.20  0.55
# 52   CJ제일제당   8.82   3.16  0.89
# 53    삼성중공업  -3.01 -21.88  0.79
# 54   맥쿼리인프라    NaN    NaN   NaN
# 55     현대건설   9.12   6.30  0.59
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                   종목명     PER    ROE   PBR
# N
# 101  KODEX 200선물인버스2X     NaN    NaN   NaN
# 102               오뚜기   18.22   7.79  1.52
# 103               팬오션   14.51   5.49  0.67
# 104              제일기획   14.88  15.09  2.04
# 105              부광약품 -192.17  -2.00  6.95
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#             종목명    PER    ROE    PBR
# N
# 151       한솔케미칼  12.91  20.88   2.68
# 152      더블유게임즈  10.74  18.93   1.60
# 153        태영건설  11.97   8.38   0.96
# 154  KBSTAR 200    NaN    NaN    NaN
# 155       두산솔루스  87.25    NaN  10.18
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                 종목명     PER   ROE   PBR
# N
# 201            대한유화   45.08  6.11  0.45
# 202            제일약품 -113.64 -5.96  4.65
# 203            롯데제과   27.16  3.19  0.68
# 204  KODEX 단기채권PLUS     NaN   NaN   NaN
# 205              후성  432.00  3.85  3.77
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#            종목명    PER    ROE   PBR
# N
# 251        풀무원  38.65   0.95  1.55
# 252     미래에셋생명   6.02   4.98  0.22
# 253    SK디스커버리   2.54  11.52  0.35
# 254      효성티앤씨   6.39  20.86  1.12
# 255  KOSEF 200    NaN    NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                종목명      PER    ROE   PBR
# N
# 301  TIGER 단기채권액티브      NaN    NaN   NaN
# 302             LF     8.06   5.65  0.33
# 303       하이트진로홀딩스  1093.75  -4.65  0.87
# 304    KOSEF 200TR      NaN    NaN   NaN
# 305           우리종금     7.43  15.63  1.07
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#               종목명    PER    ROE   PBR
# N
# 351          송원산업   9.23   8.24  0.77
# 352            경방   9.21   6.02  0.44
# 353         한국쉘석유  14.89  21.30  4.04
# 354  HANARO 단기통안채    NaN    NaN   NaN
# 355   TIGER TOP10    NaN    NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#             종목명    PER    ROE   PBR
# N
# 401   SBS미디어홀딩스  -3.68 -16.34  0.42
# 402        신성통상 -69.04   2.26  1.11
# 403          E1 -13.02  -3.63  0.22
# 404      에이블씨엔씨 -13.47  -3.94  1.04
# 405  아모레G3우(전환)  32.60    NaN  0.99
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                          종목명    PER    ROE   PBR
# N
# 451                    한국주철관  21.41   2.54  0.76
# 452                     동부건설   2.92  15.30  0.52
# 453                  넥스트사이언스  -8.61 -30.34  2.36
# 454  TIGER 차이나CSI300레버리지(합성)    NaN    NaN   NaN
# 455                     한국철강  10.96   2.65  0.29
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                             종목명     PER   ROE   PBR
# N
# 501         KBSTAR 코스닥150선물레버리지     NaN   NaN   NaN
# 502                KINDEX 200TR     NaN   NaN   NaN
# 503  TRUE 인버스 2X 천연가스 선물 ETN(H)     NaN   NaN   NaN
# 504                       세진중공업 -236.58  1.52  1.10
# 505                        성신양회   19.92  4.43  0.46
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#            종목명    PER    ROE   PBR
# N
# 551    코오롱플라스틱  44.38   2.75  0.78
# 552        쌍방울  -2.20 -19.68  0.87
# 553       세아제강   6.53   4.42  0.26
# 554  HDC아이콘트롤스 -29.64  -3.13  0.90
# 555    NH투자증권우   7.06    NaN  0.45
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#          종목명    PER    ROE   PBR
# N
# 601       벽산 -30.48  -1.18  0.49
# 602      STX  -7.27 -54.53  2.28
# 603      BYC   6.92   6.60  0.40
# 604     화성산업   5.35   2.06  0.33
# 605  현대비앤지스틸   5.82   5.55  0.32
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                    종목명    PER    ROE   PBR
# N
# 651  TIGER 코스닥150 레버리지    NaN    NaN   NaN
# 652                퍼스텍 -15.42 -31.41  5.05
# 653             인천도시가스  11.97   5.87  0.58
# 654            YG PLUS -14.40  -3.48  1.29
# 655               보해양조  -6.77 -19.66  1.37
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#          종목명     PER   ROE   PBR
# N
# 701     한양증권    3.65  7.85  0.33
# 702      휴니드    9.74  7.10  0.78
# 703    콤텍시스템  279.00  1.22  1.03
# 704    우리들제약  -60.00  0.54  1.39
# 705  KC그린홀딩스   11.73  4.61  0.52
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#       종목명     PER   ROE   PBR
# N
# 751   다스코  -51.42  1.51  0.67
# 752  영화금속  141.92  0.38  1.10
# 753  호전실업   40.35  2.26  0.70
# 754  화천기계  -15.14 -4.93  0.61
# 755  사조오양    5.35  8.18  0.49
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                      종목명     PER    ROE   PBR
# N
# 801                유양디앤유   -1.99  -8.52  1.39
# 802                 메타랩스   -2.96 -40.07  1.23
# 803               대림B&Co -132.81   1.37  0.45
# 804  신한 레버리지 은 선물 ETN(H)     NaN    NaN   NaN
# 805                 대원화성   18.39   5.56  0.87
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                  종목명     PER    ROE   PBR
# N
# 851              체시스  -44.18 -13.41  2.16
# 852    KBSTAR 금융채액티브     NaN    NaN   NaN
# 853  KB KQ 우량주30 ETN     NaN    NaN   NaN
# 854           상신브레이크  -20.11   2.40  0.32
# 855             대교우B -135.23    NaN  0.44
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                   종목명    PER    ROE   PBR
# N
# 901             평화홀딩스  -3.43 -11.10  0.38
# 902              한성기업  -2.92    NaN  0.87
# 903             호텔신라우  56.24    NaN  2.81
# 904  대신 철광석 선물 ETN(H)    NaN    NaN   NaN
# 905             삼아알미늄   9.20   4.62  0.42
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                      종목명    PER   ROE   PBR
# N
# 951  신한 레버리지 천연가스 선물 ETN    NaN   NaN   NaN
# 952         KBSTAR 국고채3년    NaN   NaN   NaN
# 953                 이화산업 -10.11 -4.35  0.37
# 954         KOSEF 코스닥150    NaN   NaN   NaN
# 955                케이탑리츠   6.57  8.22  0.54
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명     PER    ROE   PBR
# N
# 1001     KINDEX 중장기국공채액티브     NaN    NaN   NaN
# 1002              하이골드12호    4.11  17.18  0.95
# 1003                 흥아해운   -0.52 -98.70  1.05
# 1004                일양약품우  154.94    NaN  6.33
# 1005  삼성 레버리지 금 선물 ETN(H)     NaN    NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명  PER  ROE  PBR
# N
# 1051      KOSEF 200선물레버리지  NaN  NaN  NaN
# 1052    ARIRANG KS로우볼가중TR  NaN  NaN  NaN
# 1053  신한 레버리지 미국달러 선물 ETN  NaN  NaN  NaN
# 1054   미래에셋 유럽 중형주 ETN(H)  NaN  NaN  NaN
# 1055       ARIRANG 단기우량채권  NaN  NaN  NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                            종목명     PER  ROE   PBR
# N
# 1101  TRUE 레버리지 유로스탁스50 ETN(H)     NaN  NaN   NaN
# 1102            QV 조선 TOP5 ETN     NaN  NaN   NaN
# 1103       KOSEF 인도Nifty50(합성)     NaN  NaN   NaN
# 1104                  하이트진로2우B  265.22  NaN  1.25
# 1105             HANARO KRX300     NaN  NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                         종목명  PER  ROE  PBR
# N
# 1151      TIGER 미국달러선물인버스2X  NaN  NaN  NaN
# 1152       HANARO 200선물레버리지  NaN  NaN  NaN
# 1153  KODEX 글로벌4차산업로보틱스(합성)  NaN  NaN  NaN
# 1154   신한 코스피 콘도르 4/10% ETN  NaN  NaN  NaN
# 1155   KODEX 미국채울트라30년선물(H)  NaN  NaN  NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                             종목명    PER  ROE   PBR
# N
# 1201         신한 인버스 금 선물 ETN(H)    NaN  NaN   NaN
# 1202                   현대비앤지스틸우  86.75  NaN  4.85
# 1203             삼성 미디어 테마주 ETN    NaN  NaN   NaN
# 1204  SMART 선진국MSCI World(합성 H)    NaN  NaN   NaN
# 1205             신한 콩 선물 ETN(H)    NaN  NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명      PER  ROE   PBR
# N
# 1251                계양전기우  4030.00  NaN  1.48
# 1252     TIGER 200커버드콜ATM      NaN  NaN   NaN
# 1253                코리아써우     9.14  NaN  0.31
# 1254   미래에셋 원유선물혼합 ETN(H)      NaN  NaN   NaN
# 1255  KODEX S&P글로벌인프라(합성)      NaN  NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                                 종목명  PER  ROE  PBR
# N
# 1301             TRUE 인버스 엔선물 ETN B  NaN  NaN  NaN
# 1302           HANARO 글로벌럭셔리S&P(합성)  NaN  NaN  NaN
# 1303  TRUE S&P500 양매도 4% OTM ETN(H)  NaN  NaN  NaN
# 1304  신한 코스피 월별 양매도 5% 콜 2206-1 ETN  NaN  NaN  NaN
# 1305         신한 인버스 달러인덱스 선물 ETN(H)  NaN  NaN  NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                      종목명  PER  ROE  PBR
# N
# 1351     HANARO 200선물인버스  NaN  NaN  NaN
# 1352    TIGER KRX300레버리지  NaN  NaN  NaN
# 1353      KINDEX 스마트하이베타  NaN  NaN  NaN
# 1354     KINDEX 삼성그룹동일가중  NaN  NaN  NaN
# 1355  KINDEX 러시아MSCI(합성)  NaN  NaN  NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                            종목명    PER  ROE   PBR
# N
# 1401             TREX 펀더멘탈 200    NaN  NaN   NaN
# 1402                     성신양회우  26.54  NaN  0.61
# 1403  QV 인버스 레버리지 MSCI 선진국 ETN    NaN  NaN   NaN
# 1404           삼성 건축자재 테마주 ETN    NaN  NaN   NaN
# 1405                 KOSEF 고배당    NaN  NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#               종목명  PER  ROE   PBR
# N
# 1451   KINDEX 인버스  NaN  NaN   NaN
# 1452       크라운제과우  5.1  NaN  0.69
# 1453   TIGER 지주회사  NaN  NaN   NaN
# 1454  KODEX 경기소비재  NaN  NaN   NaN
# 1455  KBSTAR 게임테마  NaN  NaN   NaN
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                       종목명    PER  ROE   PBR
# N
# 1501  ARIRANG 심천차이넥스트(합성)    NaN  NaN   NaN
# 1502    KINDEX 국채선물10년인버스    NaN  NaN   NaN
# 1503          TIGER 중소형가치    NaN  NaN   NaN
# 1504     ARIRANG KRX300IT    NaN  NaN   NaN
# 1505                흥국화재우  14.37  NaN  0.55
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\users\76764\appdata\local\programs\python\python38-32\lib\site-packages\urllib3\connectionpool.py:979: InsecureRequestWarning: Unverified HTTPS request is being made to host 'finance.naver.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
#                    종목명  PER  ROE  PBR
# N
# 1551        TREX 중소형가치  NaN  NaN  NaN
# 1552      KBSTAR 200금융  NaN  NaN  NaN
# 1553  TIGER 원유선물인버스(H)  NaN  NaN  NaN
# 1554   TIGER 코스닥150로우볼  NaN  NaN  NaN
# 1555    TIGER 200 철강소재  NaN  NaN  NaN
# (1557, 4)

# %%
naverfin.shape, indicators.shape
# Out:
# ((1557, 9), (1557, 4))

# %%
indicators[80:100]
# Out:
#             종목명     PER    ROE   PBR
# N
# 81         쌍용양회   19.82   7.02  1.55
# 82         삼성증권    9.33   8.15  0.56
# 83        휠라홀딩스   11.53  23.81  2.01
# 84           CJ    8.66   6.24  0.65
# 85       BGF리테일   18.44  26.46  4.47
# 86       한국항공우주   12.65  15.84  2.21
# 87      삼성엔지니어링    9.96  24.62  1.85
# 88         롯데쇼핑   -2.45  -8.14  0.25
# 89        하이트진로  533.33  -3.86  2.52
# 90       현대차2우B    7.35    NaN  0.26
# 91         현대해상    8.65   6.23  0.47
# 92          신세계  -17.10  14.24  0.64
# 93         금호석유    8.39  11.84  0.81
# 94         GS건설    5.12  11.79  0.57
# 95          SKC   18.82   3.86  1.07
# 96       한미사이언스   70.89   4.73  3.40
# 97      일진머티리얼즈   41.49   8.52  3.81
# 98        메리츠증권    4.82  15.06  0.59
# 99   KODEX 단기채권     NaN    NaN   NaN
# 100          한샘   50.36   7.32  2.73

# %%
fullsize = pd.concat([naverfin, indicators.loc[:, ['PER', 'ROE', 'PBR']]], axis=1, sort=False)
fullsize
# Out:
#                    종목명       현재가      상장주식수       시가총액       자산총계      부채총계  \
# N
# 1                 삼성전자   54900.0  5969783.0  3277411.0  3525645.0  896841.0
# 2               SK하이닉스   90100.0   728002.0   655930.0   647895.0  168463.0
# 3             삼성바이오로직스  679000.0    66165.0   449260.0    59116.0   15572.0
# 4                삼성전자우   47900.0   822887.0   394163.0        NaN       NaN
# 5                NAVER  237500.0   164263.0   390126.0   122995.0   57956.0
# ...                ...       ...        ...        ...        ...       ...
# 1553  TIGER 원유선물인버스(H)   12360.0      150.0       19.0        NaN       NaN
# 1554   TIGER 코스닥150로우볼   12760.0      140.0       18.0        NaN       NaN
# 1555    TIGER 200 철강소재    6045.0      280.0       17.0        NaN       NaN
# 1556     TIGER 200 산업재    4260.0      280.0       12.0        NaN       NaN
# 1557     KBSTAR 200산업재    7785.0      140.0       11.0        NaN       NaN
#
#           영업이익     myRoe         자본     PER    ROE    PBR
# N
# 1     277685.0  0.105632  2628804.0   17.52   8.69   1.44
# 2      27127.0  0.056582   479432.0   42.08   4.25   1.28
# 3        917.0  0.021059    43544.0  161.59   4.77  10.23
# 4          NaN       NaN        NaN   15.28    NaN   1.26
# 5       7101.0  0.109181    65039.0   61.32  10.56   5.20
# ...        ...       ...        ...     ...    ...    ...
# 1553       NaN       NaN        NaN     NaN    NaN    NaN
# 1554       NaN       NaN        NaN     NaN    NaN    NaN
# 1555       NaN       NaN        NaN     NaN    NaN    NaN
# 1556       NaN       NaN        NaN     NaN    NaN    NaN
# 1557       NaN       NaN        NaN     NaN    NaN    NaN
#
# [1557 rows x 12 columns]

# %% [markdown]
# # 투자조건 검토
# - PER, PBR 높은거 보자

# %%
fullsize.sort_values(by=['PER', 'PBR'], ascending=[False, False]).head(20)
# Out:
#              종목명      현재가     상장주식수     시가총액     자산총계     부채총계   영업이익  \
# N
# 1251       계양전기우   8060.0    1400.0    113.0      NaN      NaN    NaN
# 1526         신원우  40250.0      91.0     37.0      NaN      NaN    NaN
# 75    KODEX 레버리지  13060.0  232200.0  30325.0      NaN      NaN    NaN
# 1256       SK증권우   2825.0    3913.0    111.0      NaN      NaN    NaN
# 649        태평양물산   2265.0   49912.0   1130.0   6133.0   4290.0  432.0
# 691         계양전기   3015.0   32600.0    983.0   2799.0    954.0   32.0
# 303           LF  13900.0   29240.0   4064.0  24171.0  10256.0  875.0
# 1382   하이트진로홀딩스우  15800.0     471.0     74.0      NaN      NaN    NaN
# 283      에이프로젠제약   1870.0  241658.0   4519.0   3653.0    176.0  -20.0
# 731        신풍제약우  40450.0    2200.0    890.0      NaN      NaN    NaN
# 750         영화금속   1845.0   45451.0    839.0   2019.0   1312.0   20.0
# 368         SK증권    671.0  472590.0   3171.0  41395.0  35693.0  214.0
# 89         하이트진로  36800.0   70134.0  25809.0  32709.0  22377.0  882.0
# 157         신풍제약  21850.0   52985.0  11577.0   3807.0   1710.0   20.0
# 205           후성   8640.0   92607.0   8001.0   5289.0   2860.0  134.0
# 1373     CJ씨푸드1우  38600.0     200.0     77.0      NaN      NaN    NaN
# 484         일신석재   2395.0   77457.0   1855.0    873.0    353.0   18.0
# 150          파미셀  21250.0   59959.0  12741.0    633.0    117.0   20.0
# 1495     KG동부제철우  90500.0      53.0     48.0      NaN      NaN    NaN
# 703        콤텍시스템   1395.0   67851.0    947.0   1615.0    666.0   30.0
#
#          myRoe       자본      PER   ROE    PBR
# N
# 1251       NaN      NaN  4030.00   NaN   1.48
# 1526       NaN      NaN  4025.00   NaN  14.88
# 75         NaN      NaN  3537.50 -1.22   0.76
# 1256       NaN      NaN  2825.00   NaN   2.33
# 649   0.234400   1843.0  2265.00  6.99   0.62
# 691   0.017344   1845.0  1507.50  0.07   0.55
# 303   0.062882  13915.0  1093.75 -4.65   0.87
# 1382       NaN      NaN   987.50   NaN   0.78
# 283  -0.005752   3477.0   935.00 -4.19   1.80
# 731        NaN      NaN   898.89   NaN   9.61
# 750   0.028289    707.0   810.00 -0.27   1.73
# 368   0.037531   5702.0   671.00  5.62   0.55
# 89    0.085366  10332.0   533.33 -3.86   2.52
# 157   0.009537   2097.0   485.56  0.80   5.19
# 205   0.055167   2429.0   432.00  3.85   3.77
# 1373       NaN      NaN   424.18   NaN  21.46
# 484   0.034615    520.0   299.38  1.77   3.57
# 150   0.038760    516.0   299.30  8.78  24.32
# 1495       NaN      NaN   287.30   NaN  10.12
# 703   0.031612    949.0   279.00  1.22   1.03

# %% [markdown]
# # Hoxy, 시간 남을 때를 대비해서, 엑셀 읽어오기

# %%
sample = pd.read_excel('financial statements.xlsx')
sample
# Out:
#                            Account Name  Account No.     Balance  \
# 0                       Cash-Petty Cash         1010      449.87
# 1                      Checking Account         1110     2412.23
# 2                    Investment Account         1115   327283.53
# 3                   Accounts Receivable         1210    16586.25
# 4                      Prepaid Expenses         1420     2587.50
# 5                     Prepaid Insurance         1425     1000.00
# 6                       Inventory Asset         1310    46005.75
# 7                Property and Equipment         1510    65000.00
# 8   Accum. Depr.Property and  Equipment         1511    -6750.00
# 9   Office/Store Furniture and Fixtures         1520    12000.00
# 10  Accum. Depr. Furniture and Fixtures         1521    -9525.00
# 11                     Accounts Payable         2010   -15502.62
# 12                Pending Item Receipts         2015     -846.59
# 13                    Sales Tax Payable         2110   -11426.42
# 14                Federal Tax Liability         2210    -1517.30
# 15         Federal Tax Liability (FUTA)         2215     -145.00
# 16                  State Tax Liability         2220     -740.00
# 17                    401 (k) Liability         2230    -2000.00
# 18                 Union Dues Liability         2240      -85.00
# 19             Medical/Dental Liability         2250     -990.00
# 20                       Other Payables         2310     -500.00
# 21                     Interest Payable         2315    -2000.00
# 22                     Visa Credit Card         2610     -300.00
# 23                 Note Payable to Bank         2710   -20000.00
# 24                         Common Stock         3015    -1000.00
# 25                                 APIC         3016   -36000.00
# 26                  Owners' Withdrawals         3020    12000.00
# 27                    Retained Earnings         3025   -76484.48
# 28                                Sales         4010 -1198873.98
# 29                  Cash Discount Given         4020     3414.90
# 30                            Write off         4210        8.83
# 31            Cost of Goods - Materials         4510   870946.22
# 32                  Cash Discount Taken         4530     -770.39
# 33                       Employee Wages         5100     2800.00
# 34                                Wages         5110     5400.00
# 35                    Employee Benefits         5120      250.00
# 36                         Bank Charges         5510       25.00
# 37     Repairs and Maintenance Expenses         5710       47.63
# 38      Depreciation Expenses/Equipment         6120     1750.00
# 39      Depreciation Expenses/Furniture         6125      525.00
# 40                      Office Supplies         6210      103.47
# 41                    Insurance Vehicle         6310     2781.72
# 42                      Insurance Other         6320      200.00
# 43            Freight/Shipping Expenses         6410      292.67
# 44                      Accounting Fees         6620     6615.54
# 45                       Other Expenses         6760      240.00
# 46                      Travel Expenses         6770     -400.00
# 47         Utilities - Electric and Gas         6810     1609.56
# 48                Utilities - Telephone         6815     1147.41
# 49                    Leased Facilities         6915     6500.00
# 50                Finance Charge Income         8020       -8.35
# 51                      Interest Income         8030    -5387.03
# 52                    Interest Expenses         9010     1269.08
#
#                           Class
# 0                          Cash
# 1                          Cash
# 2         Marketable Securities
# 3           Accounts Receivable
# 4             Prepaid and Other
# 5             Prepaid and Other
# 6                     Inventory
# 7        Property and Equipment
# 8      Accumulated Depreciation
# 9        Property and Equipment
# 10     Accumulated Depreciation
# 11             Accounts Payable
# 12             Accrued Expenses
# 13             Accrued Expenses
# 14             Accrued Expenses
# 15             Accrued Expenses
# 16             Accrued Expenses
# 17             Accrued Expenses
# 18             Accrued Expenses
# 19             Accrued Expenses
# 20             Accrued Expenses
# 21             Accrued Expenses
# 22             Accrued Expenses
# 23               Long Term Debt
# 24                 Common Stock
# 25   Additional Paid in Capital
# 26                    Dividends
# 27  Beginning Retained Earnings
# 28                      Revenue
# 29                      Revenue
# 30                      Revenue
# 31           Cost of Goods Sold
# 32           Cost of Goods Sold
# 33                     Overhead
# 34                     Overhead
# 35                     Overhead
# 36                     Overhead
# 37                     Overhead
# 38                     Overhead
# 39                     Overhead
# 40                     Overhead
# 41                     Overhead
# 42                     Overhead
# 43                     Overhead
# 44                     Overhead
# 45                     Overhead
# 46                     Overhead
# 47                     Overhead
# 48                     Overhead
# 49                     Overhead
# 50                     Overhead
# 51              Interest Income
# 52             Interest Expense

# %%
sample['TestField'] = sample['Balance'] * 12
sample
# Out:
#                            Account Name  Account No.     Balance  \
# 0                       Cash-Petty Cash         1010      449.87
# 1                      Checking Account         1110     2412.23
# 2                    Investment Account         1115   327283.53
# 3                   Accounts Receivable         1210    16586.25
# 4                      Prepaid Expenses         1420     2587.50
# 5                     Prepaid Insurance         1425     1000.00
# 6                       Inventory Asset         1310    46005.75
# 7                Property and Equipment         1510    65000.00
# 8   Accum. Depr.Property and  Equipment         1511    -6750.00
# 9   Office/Store Furniture and Fixtures         1520    12000.00
# 10  Accum. Depr. Furniture and Fixtures         1521    -9525.00
# 11                     Accounts Payable         2010   -15502.62
# 12                Pending Item Receipts         2015     -846.59
# 13                    Sales Tax Payable         2110   -11426.42
# 14                Federal Tax Liability         2210    -1517.30
# 15         Federal Tax Liability (FUTA)         2215     -145.00
# 16                  State Tax Liability         2220     -740.00
# 17                    401 (k) Liability         2230    -2000.00
# 18                 Union Dues Liability         2240      -85.00
# 19             Medical/Dental Liability         2250     -990.00
# 20                       Other Payables         2310     -500.00
# 21                     Interest Payable         2315    -2000.00
# 22                     Visa Credit Card         2610     -300.00
# 23                 Note Payable to Bank         2710   -20000.00
# 24                         Common Stock         3015    -1000.00
# 25                                 APIC         3016   -36000.00
# 26                  Owners' Withdrawals         3020    12000.00
# 27                    Retained Earnings         3025   -76484.48
# 28                                Sales         4010 -1198873.98
# 29                  Cash Discount Given         4020     3414.90
# 30                            Write off         4210        8.83
# 31            Cost of Goods - Materials         4510   870946.22
# 32                  Cash Discount Taken         4530     -770.39
# 33                       Employee Wages         5100     2800.00
# 34                                Wages         5110     5400.00
# 35                    Employee Benefits         5120      250.00
# 36                         Bank Charges         5510       25.00
# 37     Repairs and Maintenance Expenses         5710       47.63
# 38      Depreciation Expenses/Equipment         6120     1750.00
# 39      Depreciation Expenses/Furniture         6125      525.00
# 40                      Office Supplies         6210      103.47
# 41                    Insurance Vehicle         6310     2781.72
# 42                      Insurance Other         6320      200.00
# 43            Freight/Shipping Expenses         6410      292.67
# 44                      Accounting Fees         6620     6615.54
# 45                       Other Expenses         6760      240.00
# 46                      Travel Expenses         6770     -400.00
# 47         Utilities - Electric and Gas         6810     1609.56
# 48                Utilities - Telephone         6815     1147.41
# 49                    Leased Facilities         6915     6500.00
# 50                Finance Charge Income         8020       -8.35
# 51                      Interest Income         8030    -5387.03
# 52                    Interest Expenses         9010     1269.08
#
#                           Class    TestField
# 0                          Cash      5398.44
# 1                          Cash     28946.76
# 2         Marketable Securities   3927402.36
# 3           Accounts Receivable    199035.00
# 4             Prepaid and Other     31050.00
# 5             Prepaid and Other     12000.00
# 6                     Inventory    552069.00
# 7        Property and Equipment    780000.00
# 8      Accumulated Depreciation    -81000.00
# 9        Property and Equipment    144000.00
# 10     Accumulated Depreciation   -114300.00
# 11             Accounts Payable   -186031.44
# 12             Accrued Expenses    -10159.08
# 13             Accrued Expenses   -137117.04
# 14             Accrued Expenses    -18207.60
# 15             Accrued Expenses     -1740.00
# 16             Accrued Expenses     -8880.00
# 17             Accrued Expenses    -24000.00
# 18             Accrued Expenses     -1020.00
# 19             Accrued Expenses    -11880.00
# 20             Accrued Expenses     -6000.00
# 21             Accrued Expenses    -24000.00
# 22             Accrued Expenses     -3600.00
# 23               Long Term Debt   -240000.00
# 24                 Common Stock    -12000.00
# 25   Additional Paid in Capital   -432000.00
# 26                    Dividends    144000.00
# 27  Beginning Retained Earnings   -917813.76
# 28                      Revenue -14386487.76
# 29                      Revenue     40978.80
# 30                      Revenue       105.96
# 31           Cost of Goods Sold  10451354.64
# 32           Cost of Goods Sold     -9244.68
# 33                     Overhead     33600.00
# 34                     Overhead     64800.00
# 35                     Overhead      3000.00
# 36                     Overhead       300.00
# 37                     Overhead       571.56
# 38                     Overhead     21000.00
# 39                     Overhead      6300.00
# 40                     Overhead      1241.64
# 41                     Overhead     33380.64
# 42                     Overhead      2400.00
# 43                     Overhead      3512.04
# 44                     Overhead     79386.48
# 45                     Overhead      2880.00
# 46                     Overhead     -4800.00
# 47                     Overhead     19314.72
# 48                     Overhead     13768.92
# 49                     Overhead     78000.00
# 50                     Overhead      -100.20
# 51              Interest Income    -64644.36
# 52             Interest Expense     15228.96

# %%
sample.to_excel('modified_sample.xlsx')
